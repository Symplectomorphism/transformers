# %%
import routegym.env
import networkx as nx

# %%
# env = routegym.env.ShortestRouteEnv(nx.frucht_graph(), 0, 5, random_weights=(1,10))
# env = routegym.env.ShortestRouteEnv(nx.watts_strogatz_graph(8, 2, 0.5, seed=1337), 0, 5, random_weights=(1,10))
env = routegym.env.ShortestRouteEnv(nx.newman_watts_strogatz_graph(8, 2, 0.5, seed=1337), 0, 5, random_weights=(1,10))
# env = routegym.env.ShortestRouteEnv(nx.barabasi_albert_graph(8, 2, seed=1337), 0, 5, random_weights=(1,10))

# %%
env.render(human_reading_delay=1)
# Out:
# /home/icute/mambaforge/envs/dec-transformer-route/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:450: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(

# %%
done = False
print(env.graph.position)
print(env.graph.adjacent_indices[env.graph.position])
env.graph.adj_mat[env.graph.position]
# Out:
# 0
# [1 6 7]
# array([-1,  9, -1, -1, -1, -1,  2,  4, -1, -1, -1, -1])

# %%
rew = 0
position = 0
while not done:
    action = policy.predict(position)
    position, reward, done, _ = env.step(action)
    # env.render()    # optionnal
    rew += reward
print("Final reward:", rew)
print("Dijkstra's reward:", env.graph.dijkstra_rew)
