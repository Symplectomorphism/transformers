# %%
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.data import Dataset

from mingpt.model import GPT
from mingpt.trainer import Trainer
from mingpt.utils import set_seed, setup_logging, CfgNode as CN

import math
import random
from create_dataset import create_dataset
from run_shortestroute import StateActionReturnDataset

# %%
obss, actions, returns, done_idxs, rtgs, timesteps, env = create_dataset(10*1000)

train_dataset = StateActionReturnDataset(obss, 10 * 3, actions, done_idxs, rtgs, timesteps)

# Set up configs
C = CN()

## system
C.system = CN()
C.system.seed = 3407
C.system.work_dir = './out/decgpt'

# data
C.data = StateActionReturnDataset.get_default_config()

# model
C.model = GPT.get_default_config()
C.model.model_type = 'gpt-mini'
C.model.vocab_size = train_dataset.vocab_size
C.model.block_size = train_dataset.block_size
C.model.max_timestep = max(timesteps)

# trainer
C.trainer = Trainer.get_default_config()
C.trainer.learning_rate = 3e-5
C.trainer.max_epochs = 10_000
C.trainer.num_workers = 4
C.trainer.lr_decay = True
C.trainer.warmup_tokens = 30_000
C.trainer.final_tokens = 100_000_000

model = GPT(C.model)

# initialize a trainer instance and kick off training
trainer = Trainer(model, train_dataset, C.trainer)
trainer.run()

print(env.adj_mat)
env.draw()
# Out:
# max rtg is 0
# max timestep is 129
# number of parameters: 2.71M
# running on device cuda
# epoch 1 iter 155: train loss 1.86102. lr 2.999996e-05: 100%|██████████| 156/156 [00:02<00:00, 67.05it/s]
# epoch 2 iter 14: train loss 1.91429. lr 2.999995e-05:   9%|▉         | 14/156 [00:00<00:02, 67.51it/s]

# %%
model.eval()
with torch.no_grad():
    done = True
    for i in range(1):
        # sample from the model
        state = torch.tensor(env.reset())
        state = state.type(torch.float32).to(trainer.device).unsqueeze(0).unsqueeze(0)
        rtgs = [-2]
        # first state is from env, first rtg is target return, and first timestep is 0
        sampled_action = model.generate(state, 1, temperature=1.0, do_sample=True, actions=None, 
                            rtgs=torch.tensor(rtgs, dtype=torch.long).to(trainer.device).unsqueeze(0).unsqueeze(-1),
                            timesteps=torch.zeros((1, 1, 1), dtype=torch.int64).to(trainer.device))


        j = 0
        all_states = state
        actions = []
        while True:
            if done:
                state, reward_sum, done = torch.tensor(env.reset()), 0, False
            action = sampled_action.cpu().numpy()[0, -1]
            actions += [sampled_action]
            state, reward, done, = env.step(action)
            reward_sum += reward
            j += 1

            if done:
                break

            state = torch.tensor(state).unsqueeze(0).unsqueeze(0).to(trainer.device)

            all_states = torch.cat([all_states, state], dim=0)

            rtgs += [rtgs[-1] + reward]
            print(all_states.shape)
            # print((rtgs[-1], action, state))
            # all_states has all previous states and rtgs has all revious rtgs (will be cut to block_size in trainer.generate)
            # timestep is just the current timestep
            sampled_action = model.generate(all_states.unsqueeze(0), 1, temperature=1.0, do_sample=True, 
                            actions=torch.tensor(actions, dtype=torch.long).to(trainer.device).unsqueeze(-1).unsqueeze(0),
                            rtgs=torch.tensor(rtgs, dtype=torch.long).to(trainer.device).unsqueeze(0).unsqueeze(-1),
                            timesteps=(min(j, model.config.max_timestep) * torch.ones((1, 1, 1), dtype=torch.int64).to(trainer.device)))
print((rtgs[-1], action, state))
# Out:
# (-3, 0, tensor([[0]], device='cuda:0'))
# (-4, 4, tensor([[0]], device='cuda:0'))
# (-5, 10, tensor([[0]], device='cuda:0'))
# (-6, 0, tensor([[0]], device='cuda:0'))
# (-7, 6, tensor([[0]], device='cuda:0'))
# (-8, 4, tensor([[0]], device='cuda:0'))
# (-9, 1, tensor([[0]], device='cuda:0'))
# (-10, 8, tensor([[0]], device='cuda:0'))
# (-11, 1, tensor([[0]], device='cuda:0'))
# (-12, 0, tensor([[0]], device='cuda:0'))
# (-13, 4, tensor([[0]], device='cuda:0'))
# (-14, 8, tensor([[0]], device='cuda:0'))
# (-15, 4, tensor([[0]], device='cuda:0'))
# (-16, 0, tensor([[0]], device='cuda:0'))
# (-17, 0, tensor([[0]], device='cuda:0'))
# (-18, 1, tensor([[0]], device='cuda:0'))
# (-19, 0, tensor([[0]], device='cuda:0'))
# (-20, 4, tensor([[0]], device='cuda:0'))
# (-21, 0, tensor([[0]], device='cuda:0'))
# (-22, 1, tensor([[0]], device='cuda:0'))
# (-23, 6, tensor([[0]], device='cuda:0'))
# (-24, 4, tensor([[0]], device='cuda:0'))
# (-25, 10, tensor([[0]], device='cuda:0'))
# (-26, 1, tensor([[0]], device='cuda:0'))
# (-27, 8, tensor([[0]], device='cuda:0'))
# (-28, 6, tensor([[0]], device='cuda:0'))
# (-29, 0, tensor([[0]], device='cuda:0'))
# (-30, 3, tensor([[3]], device='cuda:0'))
# (-31, 3, tensor([[3]], device='cuda:0'))
# (-32, 10, tensor([[3]], device='cuda:0'))
# (-33, 10, tensor([[3]], device='cuda:0'))
# (-34, 3, tensor([[3]], device='cuda:0'))
# (-35, 10, tensor([[3]], device='cuda:0'))
# (-36, 10, tensor([[3]], device='cuda:0'))
# (-37, 4, tensor([[3]], device='cuda:0'))
# (-38, 11, tensor([[3]], device='cuda:0'))
# (-39, 7, tensor([[3]], device='cuda:0'))
# (-40, 4, tensor([[3]], device='cuda:0'))
# (-41, 7, tensor([[3]], device='cuda:0'))
# (-42, 4, tensor([[3]], device='cuda:0'))
# (-43, 11, tensor([[3]], device='cuda:0'))
# (-44, 8, tensor([[3]], device='cuda:0'))
# (-45, 3, tensor([[3]], device='cuda:0'))
# (-46, 8, tensor([[3]], device='cuda:0'))
# (-47, 3, tensor([[3]], device='cuda:0'))
# (-48, 8, tensor([[3]], device='cuda:0'))
# (-49, 3, tensor([[3]], device='cuda:0'))
# (-50, 1, tensor([[3]], device='cuda:0'))
# (-51, 4, tensor([[3]], device='cuda:0'))
# (-52, 10, tensor([[3]], device='cuda:0'))
# (-53, 1, tensor([[3]], device='cuda:0'))
# (-54, 7, tensor([[3]], device='cuda:0'))
# (-55, 3, tensor([[3]], device='cuda:0'))
# (-56, 1, tensor([[3]], device='cuda:0'))
# (-57, 11, tensor([[3]], device='cuda:0'))
# (-58, 10, tensor([[3]], device='cuda:0'))
# (-59, 10, tensor([[3]], device='cuda:0'))
# (-60, 8, tensor([[3]], device='cuda:0'))
# (-61, 3, tensor([[3]], device='cuda:0'))
# (-62, 1, tensor([[3]], device='cuda:0'))
# (-63, 11, tensor([[3]], device='cuda:0'))
# (-64, 10, tensor([[3]], device='cuda:0'))
# (-65, 10, tensor([[3]], device='cuda:0'))
# (-66, 4, tensor([[3]], device='cuda:0'))
# (-67, 8, tensor([[3]], device='cuda:0'))
# (-68, 10, tensor([[3]], device='cuda:0'))
# (-69, 2, tensor([[2]], device='cuda:0'))
# (-70, 7, tensor([[2]], device='cuda:0'))
# (-71, 2, tensor([[2]], device='cuda:0'))
# (-72, 7, tensor([[2]], device='cuda:0'))
# (-73, 3, tensor([[2]], device='cuda:0'))
# (-74, 2, tensor([[2]], device='cuda:0'))
# (-75, 7, tensor([[2]], device='cuda:0'))
# (-76, 2, tensor([[2]], device='cuda:0'))
# (-77, 11, tensor([[11]], device='cuda:0'))
# (-78, 11, tensor([[11]], device='cuda:0'))
# (-79, 8, tensor([[11]], device='cuda:0'))
# (-80, 10, tensor([[11]], device='cuda:0'))
# (-81, 10, tensor([[11]], device='cuda:0'))
# (-82, 10, tensor([[11]], device='cuda:0'))
# (-83, 6, tensor([[6]], device='cuda:0'))
# (-84, 6, tensor([[6]], device='cuda:0'))
# (-85, 10, tensor([[6]], device='cuda:0'))
# (-86, 6, tensor([[6]], device='cuda:0'))
# (-87, 10, tensor([[6]], device='cuda:0'))
# (-88, 6, tensor([[6]], device='cuda:0'))
# (-89, 10, tensor([[6]], device='cuda:0'))
# (-90, 6, tensor([[6]], device='cuda:0'))
# (-90, 5, tensor([[6]], device='cuda:0'))
# (-91, 6, tensor([[6]], device='cuda:0'))
# (-91, 5, tensor([[6]], device='cuda:0'))
# (-92, 7, tensor([[6]], device='cuda:0'))
# (-92, 5, tensor([[6]], device='cuda:0'))
# (-93, 2, tensor([[6]], device='cuda:0'))
# (-94, 2, tensor([[6]], device='cuda:0'))
# (-95, 7, tensor([[6]], device='cuda:0'))
# (-96, 10, tensor([[6]], device='cuda:0'))
# (-97, 2, tensor([[6]], device='cuda:0'))
# (-98, 10, tensor([[6]], device='cuda:0'))
# (-99, 10, tensor([[6]], device='cuda:0'))
# (-100, 6, tensor([[6]], device='cuda:0'))
# (-101, 10, tensor([[6]], device='cuda:0'))
# (-102, 6, tensor([[6]], device='cuda:0'))
# (-103, 10, tensor([[6]], device='cuda:0'))
# (-104, 6, tensor([[6]], device='cuda:0'))
# (-104, 5, tensor([[6]], device='cuda:0'))
# (-105, 7, tensor([[6]], device='cuda:0'))
# (-105, 5, tensor([[6]], device='cuda:0'))
# (-106, 2, tensor([[6]], device='cuda:0'))
# (-107, 10, tensor([[6]], device='cuda:0'))
# (-108, 10, tensor([[6]], device='cuda:0'))
# (-109, 10, tensor([[6]], device='cuda:0'))
# (-110, 10, tensor([[6]], device='cuda:0'))
# (-111, 6, tensor([[6]], device='cuda:0'))
# (-111, 5, tensor([[6]], device='cuda:0'))
# (-112, 8, tensor([[6]], device='cuda:0'))
# (-113, 10, tensor([[6]], device='cuda:0'))
# (-114, 10, tensor([[6]], device='cuda:0'))
# (-115, 6, tensor([[6]], device='cuda:0'))
# (-116, 10, tensor([[6]], device='cuda:0'))
# (-117, 6, tensor([[6]], device='cuda:0'))
# (-118, 11, tensor([[11]], device='cuda:0'))
# (-119, 10, tensor([[11]], device='cuda:0'))
# (-120, 6, tensor([[6]], device='cuda:0'))
# (-121, 7, tensor([[6]], device='cuda:0'))
# (-122, 6, tensor([[6]], device='cuda:0'))
# (-123, 11, tensor([[11]], device='cuda:0'))
# (-124, 10, tensor([[11]], device='cuda:0'))
# (-125, 3, tensor([[3]], device='cuda:0'))
# (-126, 0, tensor([[0]], device='cuda:0'))
# (-127, 6, tensor([[0]], device='cuda:0'))
# (-128, 8, tensor([[0]], device='cuda:0'))
# (-129, 6, tensor([[0]], device='cuda:0'))
# (-130, 8, tensor([[0]], device='cuda:0'))
# (-131, 6, tensor([[0]], device='cuda:0'))
# (-132, 2, tensor([[2]], device='cuda:0'))
# (-133, 2, tensor([[2]], device='cuda:0'))
# (-134, 7, tensor([[2]], device='cuda:0'))
# (-135, 2, tensor([[2]], device='cuda:0'))
# (-136, 7, tensor([[2]], device='cuda:0'))
# (-137, 2, tensor([[2]], device='cuda:0'))
# (-138, 2, tensor([[2]], device='cuda:0'))
# (-139, 6, tensor([[6]], device='cuda:0'))
# (-140, 6, tensor([[6]], device='cuda:0'))
# (-141, 6, tensor([[6]], device='cuda:0'))
# (-142, 6, tensor([[6]], device='cuda:0'))
# (-143, 6, tensor([[6]], device='cuda:0'))
# (-144, 6, tensor([[6]], device='cuda:0'))
# (-145, 6, tensor([[6]], device='cuda:0'))
# (-146, 6, tensor([[6]], device='cuda:0'))
# (-147, 6, tensor([[6]], device='cuda:0'))
# (-148, 6, tensor([[6]], device='cuda:0'))
# (-149, 6, tensor([[6]], device='cuda:0'))
# (-150, 6, tensor([[6]], device='cuda:0'))
# (-151, 6, tensor([[6]], device='cuda:0'))
# (-152, 6, tensor([[6]], device='cuda:0'))
# (-153, 6, tensor([[6]], device='cuda:0'))
# (-154, 6, tensor([[6]], device='cuda:0'))
# (-155, 6, tensor([[6]], device='cuda:0'))
# (-156, 6, tensor([[6]], device='cuda:0'))
# (-157, 6, tensor([[6]], device='cuda:0'))
# (-158, 6, tensor([[6]], device='cuda:0'))
# (-159, 6, tensor([[6]], device='cuda:0'))
# (-160, 6, tensor([[6]], device='cuda:0'))
# (-161, 6, tensor([[6]], device='cuda:0'))
# (-162, 6, tensor([[6]], device='cuda:0'))
# (-163, 6, tensor([[6]], device='cuda:0'))
# (-164, 6, tensor([[6]], device='cuda:0'))
# (-165, 6, tensor([[6]], device='cuda:0'))
# (-166, 6, tensor([[6]], device='cuda:0'))
# (-167, 6, tensor([[6]], device='cuda:0'))
# (-168, 6, tensor([[6]], device='cuda:0'))
# (-169, 6, tensor([[6]], device='cuda:0'))
# (-170, 6, tensor([[6]], device='cuda:0'))
# (-171, 6, tensor([[6]], device='cuda:0'))
# (-172, 6, tensor([[6]], device='cuda:0'))
# (-173, 6, tensor([[6]], device='cuda:0'))
# (-174, 6, tensor([[6]], device='cuda:0'))
# (-175, 6, tensor([[6]], device='cuda:0'))
# (-176, 6, tensor([[6]], device='cuda:0'))
# (-177, 6, tensor([[6]], device='cuda:0'))
# (-178, 6, tensor([[6]], device='cuda:0'))
# (-179, 6, tensor([[6]], device='cuda:0'))
# (-180, 6, tensor([[6]], device='cuda:0'))
# (-181, 6, tensor([[6]], device='cuda:0'))
# (-182, 6, tensor([[6]], device='cuda:0'))
# (-183, 6, tensor([[6]], device='cuda:0'))
# (-184, 6, tensor([[6]], device='cuda:0'))
# (-185, 6, tensor([[6]], device='cuda:0'))
# (-186, 6, tensor([[6]], device='cuda:0'))
# (-187, 6, tensor([[6]], device='cuda:0'))
# (-188, 6, tensor([[6]], device='cuda:0'))
# (-189, 6, tensor([[6]], device='cuda:0'))
# (-190, 6, tensor([[6]], device='cuda:0'))
# (-191, 6, tensor([[6]], device='cuda:0'))
# (-192, 6, tensor([[6]], device='cuda:0'))
# (-193, 6, tensor([[6]], device='cuda:0'))
# (-194, 6, tensor([[6]], device='cuda:0'))
# (-195, 6, tensor([[6]], device='cuda:0'))
# (-196, 6, tensor([[6]], device='cuda:0'))
# (-197, 6, tensor([[6]], device='cuda:0'))
# (-198, 6, tensor([[6]], device='cuda:0'))
# (-199, 6, tensor([[6]], device='cuda:0'))
# (-200, 6, tensor([[6]], device='cuda:0'))
# (-201, 6, tensor([[6]], device='cuda:0'))
# (-202, 6, tensor([[6]], device='cuda:0'))
# (-203, 6, tensor([[6]], device='cuda:0'))
# (-204, 6, tensor([[6]], device='cuda:0'))
# (-205, 6, tensor([[6]], device='cuda:0'))
# (-206, 6, tensor([[6]], device='cuda:0'))
# (-207, 6, tensor([[6]], device='cuda:0'))
# (-208, 6, tensor([[6]], device='cuda:0'))
# (-209, 6, tensor([[6]], device='cuda:0'))
# (-210, 6, tensor([[6]], device='cuda:0'))
# (-211, 6, tensor([[6]], device='cuda:0'))
# (-212, 6, tensor([[6]], device='cuda:0'))
# (-213, 6, tensor([[6]], device='cuda:0'))
# (-214, 6, tensor([[6]], device='cuda:0'))
# (-215, 6, tensor([[6]], device='cuda:0'))
# (-216, 6, tensor([[6]], device='cuda:0'))
# (-217, 6, tensor([[6]], device='cuda:0'))
# (-218, 6, tensor([[6]], device='cuda:0'))
# (-219, 6, tensor([[6]], device='cuda:0'))
# (-220, 6, tensor([[6]], device='cuda:0'))
# (-221, 6, tensor([[6]], device='cuda:0'))
# (-222, 6, tensor([[6]], device='cuda:0'))
# (-223, 6, tensor([[6]], device='cuda:0'))
# (-224, 6, tensor([[6]], device='cuda:0'))
# (-225, 6, tensor([[6]], device='cuda:0'))
# (-226, 6, tensor([[6]], device='cuda:0'))
# (-227, 6, tensor([[6]], device='cuda:0'))
# (-228, 6, tensor([[6]], device='cuda:0'))
# (-229, 6, tensor([[6]], device='cuda:0'))
# (-230, 6, tensor([[6]], device='cuda:0'))
# (-231, 6, tensor([[6]], device='cuda:0'))
# (-232, 6, tensor([[6]], device='cuda:0'))
# (-233, 6, tensor([[6]], device='cuda:0'))
# (-234, 6, tensor([[6]], device='cuda:0'))
# (-235, 6, tensor([[6]], device='cuda:0'))
# (-236, 6, tensor([[6]], device='cuda:0'))
# (-237, 6, tensor([[6]], device='cuda:0'))
# (-238, 6, tensor([[6]], device='cuda:0'))
# (-239, 6, tensor([[6]], device='cuda:0'))
# (-240, 6, tensor([[6]], device='cuda:0'))
# (-241, 6, tensor([[6]], device='cuda:0'))
# (-242, 6, tensor([[6]], device='cuda:0'))
# (-243, 6, tensor([[6]], device='cuda:0'))
# (-244, 6, tensor([[6]], device='cuda:0'))
# (-245, 6, tensor([[6]], device='cuda:0'))
# (-246, 6, tensor([[6]], device='cuda:0'))
# (-247, 6, tensor([[6]], device='cuda:0'))
# (-248, 6, tensor([[6]], device='cuda:0'))
# (-249, 6, tensor([[6]], device='cuda:0'))
# (-250, 6, tensor([[6]], device='cuda:0'))
# (-251, 6, tensor([[6]], device='cuda:0'))
# (-252, 6, tensor([[6]], device='cuda:0'))
# (-253, 6, tensor([[6]], device='cuda:0'))
# (-254, 6, tensor([[6]], device='cuda:0'))
# (-255, 6, tensor([[6]], device='cuda:0'))
# (-256, 6, tensor([[6]], device='cuda:0'))
# (-257, 6, tensor([[6]], device='cuda:0'))
# (-258, 6, tensor([[6]], device='cuda:0'))
# (-259, 6, tensor([[6]], device='cuda:0'))
# (-260, 6, tensor([[6]], device='cuda:0'))
# (-261, 6, tensor([[6]], device='cuda:0'))
# (-262, 6, tensor([[6]], device='cuda:0'))
# (-263, 6, tensor([[6]], device='cuda:0'))
# (-264, 8, tensor([[6]], device='cuda:0'))
# (-265, 6, tensor([[6]], device='cuda:0'))
# (-266, 6, tensor([[6]], device='cuda:0'))
# (-267, 6, tensor([[6]], device='cuda:0'))
# (-268, 6, tensor([[6]], device='cuda:0'))
# (-269, 6, tensor([[6]], device='cuda:0'))
# (-270, 6, tensor([[6]], device='cuda:0'))
# (-271, 6, tensor([[6]], device='cuda:0'))
# (-272, 6, tensor([[6]], device='cuda:0'))
# (-273, 6, tensor([[6]], device='cuda:0'))
# (-274, 6, tensor([[6]], device='cuda:0'))
# (-275, 6, tensor([[6]], device='cuda:0'))
# (-276, 6, tensor([[6]], device='cuda:0'))
# (-277, 6, tensor([[6]], device='cuda:0'))
# (-278, 6, tensor([[6]], device='cuda:0'))
# (-279, 6, tensor([[6]], device='cuda:0'))
# (-280, 6, tensor([[6]], device='cuda:0'))
# (-281, 6, tensor([[6]], device='cuda:0'))
# (-282, 6, tensor([[6]], device='cuda:0'))
# (-283, 6, tensor([[6]], device='cuda:0'))
# (-284, 6, tensor([[6]], device='cuda:0'))
# (-285, 6, tensor([[6]], device='cuda:0'))
# (-286, 6, tensor([[6]], device='cuda:0'))
# (-287, 6, tensor([[6]], device='cuda:0'))
# (-288, 6, tensor([[6]], device='cuda:0'))
# (-289, 6, tensor([[6]], device='cuda:0'))
# (-290, 6, tensor([[6]], device='cuda:0'))
# (-291, 6, tensor([[6]], device='cuda:0'))
# (-292, 6, tensor([[6]], device='cuda:0'))
# (-293, 6, tensor([[6]], device='cuda:0'))
# (-294, 6, tensor([[6]], device='cuda:0'))
# (-295, 6, tensor([[6]], device='cuda:0'))
# (-296, 6, tensor([[6]], device='cuda:0'))
# (-297, 6, tensor([[6]], device='cuda:0'))
# (-298, 6, tensor([[6]], device='cuda:0'))
# (-299, 6, tensor([[6]], device='cuda:0'))
# (-300, 6, tensor([[6]], device='cuda:0'))
# (-301, 6, tensor([[6]], device='cuda:0'))
# (-302, 6, tensor([[6]], device='cuda:0'))
# (-303, 6, tensor([[6]], device='cuda:0'))
# (-304, 6, tensor([[6]], device='cuda:0'))
# (-305, 6, tensor([[6]], device='cuda:0'))
# (-306, 6, tensor([[6]], device='cuda:0'))
# (-307, 6, tensor([[6]], device='cuda:0'))
# (-308, 6, tensor([[6]], device='cuda:0'))
# (-309, 6, tensor([[6]], device='cuda:0'))
# (-310, 6, tensor([[6]], device='cuda:0'))
# (-311, 6, tensor([[6]], device='cuda:0'))
# (-312, 6, tensor([[6]], device='cuda:0'))
# (-313, 6, tensor([[6]], device='cuda:0'))
# (-314, 6, tensor([[6]], device='cuda:0'))
# (-315, 6, tensor([[6]], device='cuda:0'))
# (-316, 6, tensor([[6]], device='cuda:0'))
# (-317, 6, tensor([[6]], device='cuda:0'))
# (-318, 6, tensor([[6]], device='cuda:0'))
# (-319, 6, tensor([[6]], device='cuda:0'))
# (-320, 6, tensor([[6]], device='cuda:0'))
# (-321, 6, tensor([[6]], device='cuda:0'))
# (-322, 6, tensor([[6]], device='cuda:0'))
# (-323, 6, tensor([[6]], device='cuda:0'))
# (-324, 6, tensor([[6]], device='cuda:0'))
# (-325, 6, tensor([[6]], device='cuda:0'))
# (-326, 6, tensor([[6]], device='cuda:0'))
# (-327, 6, tensor([[6]], device='cuda:0'))
# (-328, 6, tensor([[6]], device='cuda:0'))
# (-329, 6, tensor([[6]], device='cuda:0'))
# (-330, 6, tensor([[6]], device='cuda:0'))
# (-331, 6, tensor([[6]], device='cuda:0'))
# (-332, 6, tensor([[6]], device='cuda:0'))
# (-333, 6, tensor([[6]], device='cuda:0'))
# (-334, 6, tensor([[6]], device='cuda:0'))
# (-335, 6, tensor([[6]], device='cuda:0'))
# (-336, 6, tensor([[6]], device='cuda:0'))
# (-337, 6, tensor([[6]], device='cuda:0'))
# (-338, 6, tensor([[6]], device='cuda:0'))
# (-339, 6, tensor([[6]], device='cuda:0'))
# (-340, 6, tensor([[6]], device='cuda:0'))
# (-341, 6, tensor([[6]], device='cuda:0'))
# (-342, 6, tensor([[6]], device='cuda:0'))
# (-343, 6, tensor([[6]], device='cuda:0'))
# (-344, 6, tensor([[6]], device='cuda:0'))
# (-345, 6, tensor([[6]], device='cuda:0'))
# (-346, 6, tensor([[6]], device='cuda:0'))
# (-347, 6, tensor([[6]], device='cuda:0'))
# (-348, 6, tensor([[6]], device='cuda:0'))
# (-349, 6, tensor([[6]], device='cuda:0'))
# (-350, 6, tensor([[6]], device='cuda:0'))
# (-351, 6, tensor([[6]], device='cuda:0'))
# (-352, 6, tensor([[6]], device='cuda:0'))
# (-353, 6, tensor([[6]], device='cuda:0'))
# (-354, 6, tensor([[6]], device='cuda:0'))
# (-355, 6, tensor([[6]], device='cuda:0'))
# (-356, 6, tensor([[6]], device='cuda:0'))
# (-357, 6, tensor([[6]], device='cuda:0'))
# (-358, 6, tensor([[6]], device='cuda:0'))
# (-359, 6, tensor([[6]], device='cuda:0'))
# (-360, 6, tensor([[6]], device='cuda:0'))
# (-361, 6, tensor([[6]], device='cuda:0'))
# (-362, 6, tensor([[6]], device='cuda:0'))
# (-363, 6, tensor([[6]], device='cuda:0'))
# (-364, 6, tensor([[6]], device='cuda:0'))
# (-365, 6, tensor([[6]], device='cuda:0'))
# (-366, 6, tensor([[6]], device='cuda:0'))
# (-367, 6, tensor([[6]], device='cuda:0'))
# (-368, 6, tensor([[6]], device='cuda:0'))
# (-369, 6, tensor([[6]], device='cuda:0'))
# (-370, 6, tensor([[6]], device='cuda:0'))
# (-371, 6, tensor([[6]], device='cuda:0'))
# (-372, 6, tensor([[6]], device='cuda:0'))
# (-373, 6, tensor([[6]], device='cuda:0'))
# (-374, 6, tensor([[6]], device='cuda:0'))
# (-375, 6, tensor([[6]], device='cuda:0'))
# (-376, 6, tensor([[6]], device='cuda:0'))
# (-377, 6, tensor([[6]], device='cuda:0'))
# (-378, 6, tensor([[6]], device='cuda:0'))
# (-379, 6, tensor([[6]], device='cuda:0'))
# (-380, 6, tensor([[6]], device='cuda:0'))
# (-381, 6, tensor([[6]], device='cuda:0'))
# (-382, 6, tensor([[6]], device='cuda:0'))
# (-383, 6, tensor([[6]], device='cuda:0'))
# (-384, 6, tensor([[6]], device='cuda:0'))
# (-385, 6, tensor([[6]], device='cuda:0'))
# (-386, 6, tensor([[6]], device='cuda:0'))
# (-387, 6, tensor([[6]], device='cuda:0'))
# (-388, 6, tensor([[6]], device='cuda:0'))
# (-389, 6, tensor([[6]], device='cuda:0'))
# (-390, 6, tensor([[6]], device='cuda:0'))
# (-391, 6, tensor([[6]], device='cuda:0'))
# (-392, 6, tensor([[6]], device='cuda:0'))
# (-393, 6, tensor([[6]], device='cuda:0'))
# (-394, 6, tensor([[6]], device='cuda:0'))
# (-395, 6, tensor([[6]], device='cuda:0'))
# (-396, 6, tensor([[6]], device='cuda:0'))
# (-397, 6, tensor([[6]], device='cuda:0'))
# (-398, 6, tensor([[6]], device='cuda:0'))
# (-399, 6, tensor([[6]], device='cuda:0'))
# (-400, 6, tensor([[6]], device='cuda:0'))
# (-401, 6, tensor([[6]], device='cuda:0'))
# (-402, 6, tensor([[6]], device='cuda:0'))
# (-403, 6, tensor([[6]], device='cuda:0'))
# (-404, 6, tensor([[6]], device='cuda:0'))
# (-405, 6, tensor([[6]], device='cuda:0'))
# (-406, 6, tensor([[6]], device='cuda:0'))
# (-407, 6, tensor([[6]], device='cuda:0'))
# (-408, 6, tensor([[6]], device='cuda:0'))
# (-409, 6, tensor([[6]], device='cuda:0'))
# (-410, 6, tensor([[6]], device='cuda:0'))
# (-411, 6, tensor([[6]], device='cuda:0'))
# (-412, 6, tensor([[6]], device='cuda:0'))
# (-413, 6, tensor([[6]], device='cuda:0'))
# (-414, 6, tensor([[6]], device='cuda:0'))
# (-415, 6, tensor([[6]], device='cuda:0'))
# (-416, 6, tensor([[6]], device='cuda:0'))
# (-417, 6, tensor([[6]], device='cuda:0'))
# (-418, 6, tensor([[6]], device='cuda:0'))
# (-419, 6, tensor([[6]], device='cuda:0'))
# (-420, 6, tensor([[6]], device='cuda:0'))
# (-421, 6, tensor([[6]], device='cuda:0'))
# (-422, 6, tensor([[6]], device='cuda:0'))
# (-423, 6, tensor([[6]], device='cuda:0'))
# (-424, 6, tensor([[6]], device='cuda:0'))
# (-425, 6, tensor([[6]], device='cuda:0'))
# (-426, 6, tensor([[6]], device='cuda:0'))
# (-427, 6, tensor([[6]], device='cuda:0'))
# (-428, 6, tensor([[6]], device='cuda:0'))
# (-429, 6, tensor([[6]], device='cuda:0'))
# (-430, 6, tensor([[6]], device='cuda:0'))
# (-431, 6, tensor([[6]], device='cuda:0'))
# (-432, 6, tensor([[6]], device='cuda:0'))
# (-433, 6, tensor([[6]], device='cuda:0'))
# (-434, 6, tensor([[6]], device='cuda:0'))
# (-435, 6, tensor([[6]], device='cuda:0'))
# (-436, 6, tensor([[6]], device='cuda:0'))
# (-437, 6, tensor([[6]], device='cuda:0'))
# (-438, 6, tensor([[6]], device='cuda:0'))
# (-439, 6, tensor([[6]], device='cuda:0'))
# (-440, 6, tensor([[6]], device='cuda:0'))
# (-441, 6, tensor([[6]], device='cuda:0'))
# (-442, 6, tensor([[6]], device='cuda:0'))
# (-443, 6, tensor([[6]], device='cuda:0'))
# (-444, 6, tensor([[6]], device='cuda:0'))
# (-445, 6, tensor([[6]], device='cuda:0'))
# (-446, 6, tensor([[6]], device='cuda:0'))
# (-447, 6, tensor([[6]], device='cuda:0'))
# (-448, 6, tensor([[6]], device='cuda:0'))
# (-449, 6, tensor([[6]], device='cuda:0'))
# (-450, 6, tensor([[6]], device='cuda:0'))
# (-451, 6, tensor([[6]], device='cuda:0'))
# (-452, 6, tensor([[6]], device='cuda:0'))
# (-453, 6, tensor([[6]], device='cuda:0'))
# (-454, 6, tensor([[6]], device='cuda:0'))
# (-455, 6, tensor([[6]], device='cuda:0'))
# (-456, 6, tensor([[6]], device='cuda:0'))
# (-457, 6, tensor([[6]], device='cuda:0'))
# (-458, 6, tensor([[6]], device='cuda:0'))
# (-459, 6, tensor([[6]], device='cuda:0'))
# (-460, 6, tensor([[6]], device='cuda:0'))
# (-461, 6, tensor([[6]], device='cuda:0'))
# (-462, 6, tensor([[6]], device='cuda:0'))
# (-463, 6, tensor([[6]], device='cuda:0'))
# (-464, 6, tensor([[6]], device='cuda:0'))
# (-465, 6, tensor([[6]], device='cuda:0'))
# (-466, 6, tensor([[6]], device='cuda:0'))
# (-467, 6, tensor([[6]], device='cuda:0'))
# (-468, 6, tensor([[6]], device='cuda:0'))
# (-469, 6, tensor([[6]], device='cuda:0'))
# (-470, 6, tensor([[6]], device='cuda:0'))
# (-471, 6, tensor([[6]], device='cuda:0'))
# (-472, 6, tensor([[6]], device='cuda:0'))
# (-473, 6, tensor([[6]], device='cuda:0'))
# (-474, 6, tensor([[6]], device='cuda:0'))
# (-475, 6, tensor([[6]], device='cuda:0'))
# (-476, 6, tensor([[6]], device='cuda:0'))
# (-477, 6, tensor([[6]], device='cuda:0'))
# (-478, 6, tensor([[6]], device='cuda:0'))
# (-479, 6, tensor([[6]], device='cuda:0'))
# (-480, 6, tensor([[6]], device='cuda:0'))
# (-481, 6, tensor([[6]], device='cuda:0'))
# (-482, 6, tensor([[6]], device='cuda:0'))
# (-483, 6, tensor([[6]], device='cuda:0'))
# (-484, 6, tensor([[6]], device='cuda:0'))
# (-485, 6, tensor([[6]], device='cuda:0'))
# (-486, 6, tensor([[6]], device='cuda:0'))
# (-487, 6, tensor([[6]], device='cuda:0'))
# (-488, 6, tensor([[6]], device='cuda:0'))
# (-489, 6, tensor([[6]], device='cuda:0'))
# (-490, 6, tensor([[6]], device='cuda:0'))
# (-491, 6, tensor([[6]], device='cuda:0'))
# (-492, 6, tensor([[6]], device='cuda:0'))
# (-493, 6, tensor([[6]], device='cuda:0'))
# (-494, 6, tensor([[6]], device='cuda:0'))
# (-495, 6, tensor([[6]], device='cuda:0'))
# (-496, 6, tensor([[6]], device='cuda:0'))
# (-497, 6, tensor([[6]], device='cuda:0'))
# (-498, 6, tensor([[6]], device='cuda:0'))
# (-499, 6, tensor([[6]], device='cuda:0'))
# (-500, 6, tensor([[6]], device='cuda:0'))
# (-501, 6, tensor([[6]], device='cuda:0'))
# (-502, 6, tensor([[6]], device='cuda:0'))
# (-503, 6, tensor([[6]], device='cuda:0'))
# (-504, 6, tensor([[6]], device='cuda:0'))
# (-505, 6, tensor([[6]], device='cuda:0'))
# (-506, 6, tensor([[6]], device='cuda:0'))
# (-507, 6, tensor([[6]], device='cuda:0'))
# (-508, 6, tensor([[6]], device='cuda:0'))
# (-509, 6, tensor([[6]], device='cuda:0'))
# (-510, 6, tensor([[6]], device='cuda:0'))
# (-511, 6, tensor([[6]], device='cuda:0'))
# (-512, 6, tensor([[6]], device='cuda:0'))
# (-513, 6, tensor([[6]], device='cuda:0'))
# (-514, 6, tensor([[6]], device='cuda:0'))
# (-515, 6, tensor([[6]], device='cuda:0'))
# (-516, 6, tensor([[6]], device='cuda:0'))
# (-517, 6, tensor([[6]], device='cuda:0'))
# (-518, 6, tensor([[6]], device='cuda:0'))
# (-519, 6, tensor([[6]], device='cuda:0'))
# (-520, 6, tensor([[6]], device='cuda:0'))
# (-521, 6, tensor([[6]], device='cuda:0'))
# (-522, 6, tensor([[6]], device='cuda:0'))
# (-523, 6, tensor([[6]], device='cuda:0'))
# (-524, 6, tensor([[6]], device='cuda:0'))
# (-525, 6, tensor([[6]], device='cuda:0'))
# (-526, 6, tensor([[6]], device='cuda:0'))
# (-527, 6, tensor([[6]], device='cuda:0'))
# (-528, 6, tensor([[6]], device='cuda:0'))
# (-529, 6, tensor([[6]], device='cuda:0'))
# (-530, 6, tensor([[6]], device='cuda:0'))
# (-531, 6, tensor([[6]], device='cuda:0'))
# (-532, 6, tensor([[6]], device='cuda:0'))
# (-533, 6, tensor([[6]], device='cuda:0'))
# (-534, 6, tensor([[6]], device='cuda:0'))
# (-535, 6, tensor([[6]], device='cuda:0'))
# (-536, 6, tensor([[6]], device='cuda:0'))
# (-537, 6, tensor([[6]], device='cuda:0'))
# (-538, 6, tensor([[6]], device='cuda:0'))
# (-539, 6, tensor([[6]], device='cuda:0'))
# (-540, 6, tensor([[6]], device='cuda:0'))
# (-541, 6, tensor([[6]], device='cuda:0'))
# (-542, 6, tensor([[6]], device='cuda:0'))
# (-543, 6, tensor([[6]], device='cuda:0'))
# (-544, 6, tensor([[6]], device='cuda:0'))
# (-545, 6, tensor([[6]], device='cuda:0'))
# (-546, 6, tensor([[6]], device='cuda:0'))
# (-547, 6, tensor([[6]], device='cuda:0'))
# (-548, 6, tensor([[6]], device='cuda:0'))
# (-549, 6, tensor([[6]], device='cuda:0'))
# (-550, 6, tensor([[6]], device='cuda:0'))
# (-551, 6, tensor([[6]], device='cuda:0'))
# (-552, 6, tensor([[6]], device='cuda:0'))
# (-553, 6, tensor([[6]], device='cuda:0'))
# (-554, 6, tensor([[6]], device='cuda:0'))
# (-555, 6, tensor([[6]], device='cuda:0'))
# (-556, 6, tensor([[6]], device='cuda:0'))
# (-557, 6, tensor([[6]], device='cuda:0'))
# (-558, 6, tensor([[6]], device='cuda:0'))
# (-559, 6, tensor([[6]], device='cuda:0'))
# (-560, 6, tensor([[6]], device='cuda:0'))
# (-561, 6, tensor([[6]], device='cuda:0'))
# (-562, 6, tensor([[6]], device='cuda:0'))
# (-563, 6, tensor([[6]], device='cuda:0'))
# (-564, 6, tensor([[6]], device='cuda:0'))
# (-565, 6, tensor([[6]], device='cuda:0'))
# (-566, 6, tensor([[6]], device='cuda:0'))
# (-567, 6, tensor([[6]], device='cuda:0'))
# (-568, 6, tensor([[6]], device='cuda:0'))
# (-569, 6, tensor([[6]], device='cuda:0'))
# (-570, 6, tensor([[6]], device='cuda:0'))
# (-571, 6, tensor([[6]], device='cuda:0'))
# (-572, 6, tensor([[6]], device='cuda:0'))
# (-573, 6, tensor([[6]], device='cuda:0'))
# (-574, 6, tensor([[6]], device='cuda:0'))
# (-575, 6, tensor([[6]], device='cuda:0'))
# (-576, 6, tensor([[6]], device='cuda:0'))
# (-577, 6, tensor([[6]], device='cuda:0'))
# (-578, 6, tensor([[6]], device='cuda:0'))
# (-579, 6, tensor([[6]], device='cuda:0'))
# (-580, 6, tensor([[6]], device='cuda:0'))
# (-581, 6, tensor([[6]], device='cuda:0'))
# (-582, 6, tensor([[6]], device='cuda:0'))
# (-583, 6, tensor([[6]], device='cuda:0'))
# (-584, 6, tensor([[6]], device='cuda:0'))
# (-585, 6, tensor([[6]], device='cuda:0'))
# (-586, 6, tensor([[6]], device='cuda:0'))
# (-587, 6, tensor([[6]], device='cuda:0'))
# (-588, 6, tensor([[6]], device='cuda:0'))
# (-589, 6, tensor([[6]], device='cuda:0'))
# (-590, 6, tensor([[6]], device='cuda:0'))
# (-591, 6, tensor([[6]], device='cuda:0'))
# (-592, 6, tensor([[6]], device='cuda:0'))
# (-593, 6, tensor([[6]], device='cuda:0'))
# (-594, 6, tensor([[6]], device='cuda:0'))
# (-595, 6, tensor([[6]], device='cuda:0'))
# (-596, 6, tensor([[6]], device='cuda:0'))
# (-597, 6, tensor([[6]], device='cuda:0'))
# (-598, 6, tensor([[6]], device='cuda:0'))
# (-599, 6, tensor([[6]], device='cuda:0'))
# (-600, 6, tensor([[6]], device='cuda:0'))
# (-601, 6, tensor([[6]], device='cuda:0'))
# (-602, 6, tensor([[6]], device='cuda:0'))
# (-603, 6, tensor([[6]], device='cuda:0'))
# (-604, 6, tensor([[6]], device='cuda:0'))
# (-605, 6, tensor([[6]], device='cuda:0'))
# (-606, 6, tensor([[6]], device='cuda:0'))
# (-607, 6, tensor([[6]], device='cuda:0'))
# (-608, 6, tensor([[6]], device='cuda:0'))
# (-609, 6, tensor([[6]], device='cuda:0'))
# (-610, 6, tensor([[6]], device='cuda:0'))
# (-611, 6, tensor([[6]], device='cuda:0'))
# (-612, 6, tensor([[6]], device='cuda:0'))
# (-613, 6, tensor([[6]], device='cuda:0'))
# (-614, 6, tensor([[6]], device='cuda:0'))
# (-615, 6, tensor([[6]], device='cuda:0'))
# (-616, 6, tensor([[6]], device='cuda:0'))
# (-617, 6, tensor([[6]], device='cuda:0'))
# (-618, 6, tensor([[6]], device='cuda:0'))
# (-619, 6, tensor([[6]], device='cuda:0'))
# (-620, 6, tensor([[6]], device='cuda:0'))
# (-621, 6, tensor([[6]], device='cuda:0'))
# (-622, 6, tensor([[6]], device='cuda:0'))
# (-623, 6, tensor([[6]], device='cuda:0'))
# (-624, 6, tensor([[6]], device='cuda:0'))
# (-625, 6, tensor([[6]], device='cuda:0'))
# (-626, 6, tensor([[6]], device='cuda:0'))
# (-627, 6, tensor([[6]], device='cuda:0'))
# (-628, 6, tensor([[6]], device='cuda:0'))
# (-629, 6, tensor([[6]], device='cuda:0'))
# (-630, 6, tensor([[6]], device='cuda:0'))
# (-631, 6, tensor([[6]], device='cuda:0'))
# (-632, 6, tensor([[6]], device='cuda:0'))
# (-633, 6, tensor([[6]], device='cuda:0'))
# (-634, 6, tensor([[6]], device='cuda:0'))
# (-635, 6, tensor([[6]], device='cuda:0'))
# (-636, 6, tensor([[6]], device='cuda:0'))
# (-637, 6, tensor([[6]], device='cuda:0'))
# (-638, 6, tensor([[6]], device='cuda:0'))
# (-639, 6, tensor([[6]], device='cuda:0'))
# (-640, 6, tensor([[6]], device='cuda:0'))
# (-641, 6, tensor([[6]], device='cuda:0'))
# (-642, 6, tensor([[6]], device='cuda:0'))
# (-643, 6, tensor([[6]], device='cuda:0'))
# (-644, 6, tensor([[6]], device='cuda:0'))
# (-645, 6, tensor([[6]], device='cuda:0'))
# (-646, 6, tensor([[6]], device='cuda:0'))
# (-647, 6, tensor([[6]], device='cuda:0'))
# (-648, 6, tensor([[6]], device='cuda:0'))
# (-649, 6, tensor([[6]], device='cuda:0'))
# (-650, 6, tensor([[6]], device='cuda:0'))
# (-651, 6, tensor([[6]], device='cuda:0'))
# (-652, 6, tensor([[6]], device='cuda:0'))
# (-653, 6, tensor([[6]], device='cuda:0'))
# (-654, 6, tensor([[6]], device='cuda:0'))
# (-655, 6, tensor([[6]], device='cuda:0'))
# (-656, 6, tensor([[6]], device='cuda:0'))
# (-657, 6, tensor([[6]], device='cuda:0'))
# (-658, 6, tensor([[6]], device='cuda:0'))
# (-659, 6, tensor([[6]], device='cuda:0'))
# (-660, 6, tensor([[6]], device='cuda:0'))
# (-661, 6, tensor([[6]], device='cuda:0'))
# (-662, 6, tensor([[6]], device='cuda:0'))
# (-663, 6, tensor([[6]], device='cuda:0'))
# (-664, 6, tensor([[6]], device='cuda:0'))
# (-665, 6, tensor([[6]], device='cuda:0'))
# (-666, 6, tensor([[6]], device='cuda:0'))
# (-667, 6, tensor([[6]], device='cuda:0'))
# (-668, 6, tensor([[6]], device='cuda:0'))
# (-669, 6, tensor([[6]], device='cuda:0'))
# (-670, 6, tensor([[6]], device='cuda:0'))
# (-671, 6, tensor([[6]], device='cuda:0'))
# (-672, 6, tensor([[6]], device='cuda:0'))
# (-673, 6, tensor([[6]], device='cuda:0'))
# (-674, 6, tensor([[6]], device='cuda:0'))
# (-675, 6, tensor([[6]], device='cuda:0'))
# (-676, 6, tensor([[6]], device='cuda:0'))
# (-677, 6, tensor([[6]], device='cuda:0'))
# (-678, 6, tensor([[6]], device='cuda:0'))
# (-679, 6, tensor([[6]], device='cuda:0'))
# (-680, 6, tensor([[6]], device='cuda:0'))
# (-681, 6, tensor([[6]], device='cuda:0'))
# (-682, 6, tensor([[6]], device='cuda:0'))
# (-683, 6, tensor([[6]], device='cuda:0'))
# (-684, 6, tensor([[6]], device='cuda:0'))
# (-685, 6, tensor([[6]], device='cuda:0'))
# (-686, 6, tensor([[6]], device='cuda:0'))
# (-687, 6, tensor([[6]], device='cuda:0'))
# (-688, 6, tensor([[6]], device='cuda:0'))
# (-689, 6, tensor([[6]], device='cuda:0'))
# (-690, 6, tensor([[6]], device='cuda:0'))
# (-691, 6, tensor([[6]], device='cuda:0'))
# (-692, 6, tensor([[6]], device='cuda:0'))
# (-693, 6, tensor([[6]], device='cuda:0'))
# (-694, 6, tensor([[6]], device='cuda:0'))
# (-695, 6, tensor([[6]], device='cuda:0'))
# (-696, 6, tensor([[6]], device='cuda:0'))
# (-697, 6, tensor([[6]], device='cuda:0'))
# (-698, 6, tensor([[6]], device='cuda:0'))
# (-699, 6, tensor([[6]], device='cuda:0'))
# (-700, 6, tensor([[6]], device='cuda:0'))
# (-701, 6, tensor([[6]], device='cuda:0'))
# (-702, 6, tensor([[6]], device='cuda:0'))
# (-703, 6, tensor([[6]], device='cuda:0'))
# (-704, 6, tensor([[6]], device='cuda:0'))
# (-705, 6, tensor([[6]], device='cuda:0'))
# (-706, 6, tensor([[6]], device='cuda:0'))
# (-707, 6, tensor([[6]], device='cuda:0'))
# (-708, 6, tensor([[6]], device='cuda:0'))
# (-709, 6, tensor([[6]], device='cuda:0'))
# (-710, 6, tensor([[6]], device='cuda:0'))
# (-711, 6, tensor([[6]], device='cuda:0'))
# (-712, 6, tensor([[6]], device='cuda:0'))
# (-713, 6, tensor([[6]], device='cuda:0'))
# (-714, 6, tensor([[6]], device='cuda:0'))
# (-715, 6, tensor([[6]], device='cuda:0'))
# (-716, 6, tensor([[6]], device='cuda:0'))
# (-717, 6, tensor([[6]], device='cuda:0'))
# (-718, 6, tensor([[6]], device='cuda:0'))
# (-719, 6, tensor([[6]], device='cuda:0'))
# (-720, 6, tensor([[6]], device='cuda:0'))
# (-721, 6, tensor([[6]], device='cuda:0'))
# (-722, 6, tensor([[6]], device='cuda:0'))
# (-723, 6, tensor([[6]], device='cuda:0'))
# (-724, 6, tensor([[6]], device='cuda:0'))
# (-725, 6, tensor([[6]], device='cuda:0'))
# (-726, 6, tensor([[6]], device='cuda:0'))
# (-727, 6, tensor([[6]], device='cuda:0'))
# (-728, 6, tensor([[6]], device='cuda:0'))
# (-729, 6, tensor([[6]], device='cuda:0'))
# (-730, 6, tensor([[6]], device='cuda:0'))
# (-731, 6, tensor([[6]], device='cuda:0'))
# (-732, 6, tensor([[6]], device='cuda:0'))
# (-733, 6, tensor([[6]], device='cuda:0'))
# (-734, 6, tensor([[6]], device='cuda:0'))
# (-735, 6, tensor([[6]], device='cuda:0'))
# (-736, 6, tensor([[6]], device='cuda:0'))
# (-737, 6, tensor([[6]], device='cuda:0'))
# (-738, 6, tensor([[6]], device='cuda:0'))
# (-739, 6, tensor([[6]], device='cuda:0'))
# (-740, 6, tensor([[6]], device='cuda:0'))
# (-741, 6, tensor([[6]], device='cuda:0'))
# (-742, 6, tensor([[6]], device='cuda:0'))
# (-743, 6, tensor([[6]], device='cuda:0'))
# (-744, 6, tensor([[6]], device='cuda:0'))
# (-745, 6, tensor([[6]], device='cuda:0'))
# (-746, 6, tensor([[6]], device='cuda:0'))
# (-747, 6, tensor([[6]], device='cuda:0'))
# (-748, 6, tensor([[6]], device='cuda:0'))
# (-749, 6, tensor([[6]], device='cuda:0'))
# (-750, 6, tensor([[6]], device='cuda:0'))
# (-751, 6, tensor([[6]], device='cuda:0'))
# (-752, 6, tensor([[6]], device='cuda:0'))
# (-753, 6, tensor([[6]], device='cuda:0'))
# (-754, 6, tensor([[6]], device='cuda:0'))
# (-755, 6, tensor([[6]], device='cuda:0'))
# (-756, 6, tensor([[6]], device='cuda:0'))
# (-757, 6, tensor([[6]], device='cuda:0'))
# (-758, 6, tensor([[6]], device='cuda:0'))
# (-759, 6, tensor([[6]], device='cuda:0'))
# (-760, 6, tensor([[6]], device='cuda:0'))
# (-761, 6, tensor([[6]], device='cuda:0'))
# (-762, 6, tensor([[6]], device='cuda:0'))
# (-763, 6, tensor([[6]], device='cuda:0'))
# (-764, 6, tensor([[6]], device='cuda:0'))
# (-765, 6, tensor([[6]], device='cuda:0'))
# (-766, 6, tensor([[6]], device='cuda:0'))
# (-767, 6, tensor([[6]], device='cuda:0'))
# (-768, 6, tensor([[6]], device='cuda:0'))
# (-769, 6, tensor([[6]], device='cuda:0'))
# (-770, 6, tensor([[6]], device='cuda:0'))
# (-771, 6, tensor([[6]], device='cuda:0'))
# (-772, 6, tensor([[6]], device='cuda:0'))
# (-773, 6, tensor([[6]], device='cuda:0'))
# (-774, 6, tensor([[6]], device='cuda:0'))
# (-775, 6, tensor([[6]], device='cuda:0'))
# (-776, 6, tensor([[6]], device='cuda:0'))
# (-777, 6, tensor([[6]], device='cuda:0'))
# (-778, 6, tensor([[6]], device='cuda:0'))
# (-779, 6, tensor([[6]], device='cuda:0'))
# (-780, 6, tensor([[6]], device='cuda:0'))
# (-781, 6, tensor([[6]], device='cuda:0'))
# (-782, 6, tensor([[6]], device='cuda:0'))
# (-783, 6, tensor([[6]], device='cuda:0'))
# (-784, 6, tensor([[6]], device='cuda:0'))
# (-785, 6, tensor([[6]], device='cuda:0'))
# (-786, 6, tensor([[6]], device='cuda:0'))
# (-787, 6, tensor([[6]], device='cuda:0'))
# (-788, 6, tensor([[6]], device='cuda:0'))
# (-789, 6, tensor([[6]], device='cuda:0'))
# (-790, 6, tensor([[6]], device='cuda:0'))
# (-791, 6, tensor([[6]], device='cuda:0'))
# (-792, 6, tensor([[6]], device='cuda:0'))
# (-793, 6, tensor([[6]], device='cuda:0'))
# (-794, 6, tensor([[6]], device='cuda:0'))
# (-795, 6, tensor([[6]], device='cuda:0'))
# (-796, 6, tensor([[6]], device='cuda:0'))
# (-797, 6, tensor([[6]], device='cuda:0'))
# (-798, 6, tensor([[6]], device='cuda:0'))
# (-799, 6, tensor([[6]], device='cuda:0'))
# (-800, 6, tensor([[6]], device='cuda:0'))
# (-801, 6, tensor([[6]], device='cuda:0'))
# (-802, 6, tensor([[6]], device='cuda:0'))
# (-803, 6, tensor([[6]], device='cuda:0'))
# (-804, 6, tensor([[6]], device='cuda:0'))
# (-805, 6, tensor([[6]], device='cuda:0'))
# (-806, 6, tensor([[6]], device='cuda:0'))
# (-807, 6, tensor([[6]], device='cuda:0'))
# (-808, 6, tensor([[6]], device='cuda:0'))
# (-809, 6, tensor([[6]], device='cuda:0'))
# (-810, 6, tensor([[6]], device='cuda:0'))
# (-811, 6, tensor([[6]], device='cuda:0'))
# (-812, 6, tensor([[6]], device='cuda:0'))
# (-813, 6, tensor([[6]], device='cuda:0'))
# (-814, 6, tensor([[6]], device='cuda:0'))
# (-815, 6, tensor([[6]], device='cuda:0'))
# (-816, 6, tensor([[6]], device='cuda:0'))
# (-817, 6, tensor([[6]], device='cuda:0'))
# (-818, 6, tensor([[6]], device='cuda:0'))
# (-819, 6, tensor([[6]], device='cuda:0'))
# (-820, 6, tensor([[6]], device='cuda:0'))
# (-821, 6, tensor([[6]], device='cuda:0'))
# (-822, 6, tensor([[6]], device='cuda:0'))
# (-823, 6, tensor([[6]], device='cuda:0'))
# (-824, 6, tensor([[6]], device='cuda:0'))
# (-825, 6, tensor([[6]], device='cuda:0'))
# (-826, 6, tensor([[6]], device='cuda:0'))
# (-827, 6, tensor([[6]], device='cuda:0'))
# (-828, 6, tensor([[6]], device='cuda:0'))
# (-829, 6, tensor([[6]], device='cuda:0'))
# (-830, 6, tensor([[6]], device='cuda:0'))
# (-831, 6, tensor([[6]], device='cuda:0'))
# (-832, 6, tensor([[6]], device='cuda:0'))
# (-833, 6, tensor([[6]], device='cuda:0'))
# (-834, 6, tensor([[6]], device='cuda:0'))
# (-835, 6, tensor([[6]], device='cuda:0'))
# (-836, 6, tensor([[6]], device='cuda:0'))
# (-837, 6, tensor([[6]], device='cuda:0'))
# (-838, 6, tensor([[6]], device='cuda:0'))
# (-839, 6, tensor([[6]], device='cuda:0'))
# (-840, 6, tensor([[6]], device='cuda:0'))
# (-841, 6, tensor([[6]], device='cuda:0'))
# (-842, 6, tensor([[6]], device='cuda:0'))
# (-843, 6, tensor([[6]], device='cuda:0'))
# (-844, 6, tensor([[6]], device='cuda:0'))
# (-845, 6, tensor([[6]], device='cuda:0'))
# (-846, 6, tensor([[6]], device='cuda:0'))
# (-847, 6, tensor([[6]], device='cuda:0'))
# (-848, 6, tensor([[6]], device='cuda:0'))
# (-849, 6, tensor([[6]], device='cuda:0'))
# (-850, 6, tensor([[6]], device='cuda:0'))
# (-851, 6, tensor([[6]], device='cuda:0'))
# (-852, 6, tensor([[6]], device='cuda:0'))
# (-853, 6, tensor([[6]], device='cuda:0'))
# (-854, 6, tensor([[6]], device='cuda:0'))
# (-855, 6, tensor([[6]], device='cuda:0'))
# (-856, 6, tensor([[6]], device='cuda:0'))
# (-857, 6, tensor([[6]], device='cuda:0'))
# (-858, 6, tensor([[6]], device='cuda:0'))
# (-859, 6, tensor([[6]], device='cuda:0'))
# (-860, 6, tensor([[6]], device='cuda:0'))
# (-861, 6, tensor([[6]], device='cuda:0'))
# (-862, 6, tensor([[6]], device='cuda:0'))
# (-863, 6, tensor([[6]], device='cuda:0'))
# (-864, 6, tensor([[6]], device='cuda:0'))
# (-865, 6, tensor([[6]], device='cuda:0'))
# (-866, 6, tensor([[6]], device='cuda:0'))
# (-867, 6, tensor([[6]], device='cuda:0'))
# (-868, 6, tensor([[6]], device='cuda:0'))
# (-869, 6, tensor([[6]], device='cuda:0'))
# (-870, 6, tensor([[6]], device='cuda:0'))
# (-871, 6, tensor([[6]], device='cuda:0'))
# (-872, 6, tensor([[6]], device='cuda:0'))
# (-873, 6, tensor([[6]], device='cuda:0'))
# (-874, 6, tensor([[6]], device='cuda:0'))
# (-875, 6, tensor([[6]], device='cuda:0'))
# (-876, 6, tensor([[6]], device='cuda:0'))
# (-877, 6, tensor([[6]], device='cuda:0'))
# (-878, 6, tensor([[6]], device='cuda:0'))
# (-879, 6, tensor([[6]], device='cuda:0'))
# (-880, 6, tensor([[6]], device='cuda:0'))
# (-881, 6, tensor([[6]], device='cuda:0'))
# (-882, 6, tensor([[6]], device='cuda:0'))
# (-883, 6, tensor([[6]], device='cuda:0'))
# (-884, 6, tensor([[6]], device='cuda:0'))
# (-885, 6, tensor([[6]], device='cuda:0'))
# (-886, 6, tensor([[6]], device='cuda:0'))
# (-887, 6, tensor([[6]], device='cuda:0'))
# (-888, 6, tensor([[6]], device='cuda:0'))
# (-889, 6, tensor([[6]], device='cuda:0'))
# (-890, 6, tensor([[6]], device='cuda:0'))
# (-891, 6, tensor([[6]], device='cuda:0'))
# (-892, 6, tensor([[6]], device='cuda:0'))
# (-893, 6, tensor([[6]], device='cuda:0'))
# (-894, 6, tensor([[6]], device='cuda:0'))
# (-895, 6, tensor([[6]], device='cuda:0'))
# (-896, 6, tensor([[6]], device='cuda:0'))
# (-897, 6, tensor([[6]], device='cuda:0'))
# (-898, 6, tensor([[6]], device='cuda:0'))
# (-899, 6, tensor([[6]], device='cuda:0'))
# (-900, 6, tensor([[6]], device='cuda:0'))
# (-901, 6, tensor([[6]], device='cuda:0'))
# (-902, 6, tensor([[6]], device='cuda:0'))
# (-903, 6, tensor([[6]], device='cuda:0'))
# (-904, 6, tensor([[6]], device='cuda:0'))
# (-905, 6, tensor([[6]], device='cuda:0'))
# (-906, 6, tensor([[6]], device='cuda:0'))
# (-907, 6, tensor([[6]], device='cuda:0'))
# (-908, 6, tensor([[6]], device='cuda:0'))
# (-909, 6, tensor([[6]], device='cuda:0'))
# (-910, 6, tensor([[6]], device='cuda:0'))
# (-911, 6, tensor([[6]], device='cuda:0'))
# (-912, 6, tensor([[6]], device='cuda:0'))
# (-913, 6, tensor([[6]], device='cuda:0'))
# (-914, 6, tensor([[6]], device='cuda:0'))
# (-915, 6, tensor([[6]], device='cuda:0'))
# (-916, 6, tensor([[6]], device='cuda:0'))
# (-917, 6, tensor([[6]], device='cuda:0'))
# (-918, 6, tensor([[6]], device='cuda:0'))
# (-919, 6, tensor([[6]], device='cuda:0'))
# (-920, 6, tensor([[6]], device='cuda:0'))
# (-921, 6, tensor([[6]], device='cuda:0'))
# (-922, 6, tensor([[6]], device='cuda:0'))
# (-923, 6, tensor([[6]], device='cuda:0'))
# (-924, 6, tensor([[6]], device='cuda:0'))
# (-925, 6, tensor([[6]], device='cuda:0'))
# (-926, 6, tensor([[6]], device='cuda:0'))
# (-927, 6, tensor([[6]], device='cuda:0'))
# (-928, 6, tensor([[6]], device='cuda:0'))
# (-929, 6, tensor([[6]], device='cuda:0'))
# (-930, 6, tensor([[6]], device='cuda:0'))
# (-931, 6, tensor([[6]], device='cuda:0'))
# (-932, 6, tensor([[6]], device='cuda:0'))
# (-933, 6, tensor([[6]], device='cuda:0'))
# (-934, 6, tensor([[6]], device='cuda:0'))
# (-935, 6, tensor([[6]], device='cuda:0'))
# (-936, 6, tensor([[6]], device='cuda:0'))
# (-937, 6, tensor([[6]], device='cuda:0'))
# (-938, 6, tensor([[6]], device='cuda:0'))
# (-939, 6, tensor([[6]], device='cuda:0'))
# (-940, 6, tensor([[6]], device='cuda:0'))
# (-941, 6, tensor([[6]], device='cuda:0'))
# (-942, 6, tensor([[6]], device='cuda:0'))
# (-943, 6, tensor([[6]], device='cuda:0'))
# (-944, 6, tensor([[6]], device='cuda:0'))
# (-945, 6, tensor([[6]], device='cuda:0'))
# (-946, 6, tensor([[6]], device='cuda:0'))
# (-947, 6, tensor([[6]], device='cuda:0'))
# (-948, 6, tensor([[6]], device='cuda:0'))
# (-949, 6, tensor([[6]], device='cuda:0'))
# (-950, 6, tensor([[6]], device='cuda:0'))
# (-951, 6, tensor([[6]], device='cuda:0'))
# (-952, 6, tensor([[6]], device='cuda:0'))
# (-953, 6, tensor([[6]], device='cuda:0'))
# (-954, 6, tensor([[6]], device='cuda:0'))
# (-955, 6, tensor([[6]], device='cuda:0'))
# (-956, 6, tensor([[6]], device='cuda:0'))
# (-957, 6, tensor([[6]], device='cuda:0'))
# (-958, 6, tensor([[6]], device='cuda:0'))
# (-959, 6, tensor([[6]], device='cuda:0'))
# (-960, 6, tensor([[6]], device='cuda:0'))
# (-961, 6, tensor([[6]], device='cuda:0'))
# (-962, 6, tensor([[6]], device='cuda:0'))
# (-963, 6, tensor([[6]], device='cuda:0'))
# (-964, 6, tensor([[6]], device='cuda:0'))
# (-965, 6, tensor([[6]], device='cuda:0'))
# (-966, 6, tensor([[6]], device='cuda:0'))
# (-967, 6, tensor([[6]], device='cuda:0'))
# (-968, 6, tensor([[6]], device='cuda:0'))
# (-969, 6, tensor([[6]], device='cuda:0'))
# (-970, 6, tensor([[6]], device='cuda:0'))
# (-971, 6, tensor([[6]], device='cuda:0'))
# (-972, 6, tensor([[6]], device='cuda:0'))
# (-973, 6, tensor([[6]], device='cuda:0'))
# (-974, 6, tensor([[6]], device='cuda:0'))
# (-975, 6, tensor([[6]], device='cuda:0'))
# (-976, 6, tensor([[6]], device='cuda:0'))
# (-977, 6, tensor([[6]], device='cuda:0'))
# (-978, 6, tensor([[6]], device='cuda:0'))
# (-979, 6, tensor([[6]], device='cuda:0'))
# (-980, 6, tensor([[6]], device='cuda:0'))
# (-981, 6, tensor([[6]], device='cuda:0'))
# (-982, 6, tensor([[6]], device='cuda:0'))
# (-983, 6, tensor([[6]], device='cuda:0'))
# (-984, 6, tensor([[6]], device='cuda:0'))
# (-985, 6, tensor([[6]], device='cuda:0'))
# (-986, 6, tensor([[6]], device='cuda:0'))
# (-987, 6, tensor([[6]], device='cuda:0'))
# (-988, 6, tensor([[6]], device='cuda:0'))
# (-989, 6, tensor([[6]], device='cuda:0'))
# (-990, 6, tensor([[6]], device='cuda:0'))
# (-991, 6, tensor([[6]], device='cuda:0'))
# (-992, 6, tensor([[6]], device='cuda:0'))
# (-993, 6, tensor([[6]], device='cuda:0'))
# (-994, 6, tensor([[6]], device='cuda:0'))
# (-995, 6, tensor([[6]], device='cuda:0'))
# (-996, 6, tensor([[6]], device='cuda:0'))
# (-997, 6, tensor([[6]], device='cuda:0'))
# (-998, 6, tensor([[6]], device='cuda:0'))
# (-999, 6, tensor([[6]], device='cuda:0'))
# (-1000, 6, tensor([[6]], device='cuda:0'))
# (-1001, 6, tensor([[6]], device='cuda:0'))
# (-1002, 6, tensor([[6]], device='cuda:0'))
# (-1003, 6, tensor([[6]], device='cuda:0'))
# (-1004, 6, tensor([[6]], device='cuda:0'))
# (-1005, 6, tensor([[6]], device='cuda:0'))
# (-1006, 6, tensor([[6]], device='cuda:0'))
# (-1007, 6, tensor([[6]], device='cuda:0'))
# (-1008, 6, tensor([[6]], device='cuda:0'))
# (-1009, 6, tensor([[6]], device='cuda:0'))
# (-1010, 6, tensor([[6]], device='cuda:0'))
# (-1011, 6, tensor([[6]], device='cuda:0'))
# (-1012, 6, tensor([[6]], device='cuda:0'))
# (-1013, 6, tensor([[6]], device='cuda:0'))
# (-1014, 6, tensor([[6]], device='cuda:0'))
# (-1015, 6, tensor([[6]], device='cuda:0'))
# (-1016, 6, tensor([[6]], device='cuda:0'))
# (-1017, 6, tensor([[6]], device='cuda:0'))
# (-1018, 6, tensor([[6]], device='cuda:0'))
# (-1019, 6, tensor([[6]], device='cuda:0'))
# (-1020, 6, tensor([[6]], device='cuda:0'))
# (-1021, 6, tensor([[6]], device='cuda:0'))
# (-1022, 6, tensor([[6]], device='cuda:0'))
# (-1023, 6, tensor([[6]], device='cuda:0'))
# (-1024, 6, tensor([[6]], device='cuda:0'))
# (-1025, 6, tensor([[6]], device='cuda:0'))
# (-1026, 6, tensor([[6]], device='cuda:0'))
# (-1027, 6, tensor([[6]], device='cuda:0'))
# (-1028, 6, tensor([[6]], device='cuda:0'))
# (-1029, 6, tensor([[6]], device='cuda:0'))
# (-1030, 6, tensor([[6]], device='cuda:0'))
# (-1031, 6, tensor([[6]], device='cuda:0'))
# (-1032, 6, tensor([[6]], device='cuda:0'))
# (-1033, 6, tensor([[6]], device='cuda:0'))
# (-1034, 6, tensor([[6]], device='cuda:0'))
# (-1035, 6, tensor([[6]], device='cuda:0'))
# (-1036, 6, tensor([[6]], device='cuda:0'))
# (-1037, 6, tensor([[6]], device='cuda:0'))
# (-1038, 6, tensor([[6]], device='cuda:0'))
# (-1039, 6, tensor([[6]], device='cuda:0'))
# (-1040, 6, tensor([[6]], device='cuda:0'))
# (-1041, 6, tensor([[6]], device='cuda:0'))
# (-1042, 6, tensor([[6]], device='cuda:0'))
# (-1043, 6, tensor([[6]], device='cuda:0'))
# (-1044, 6, tensor([[6]], device='cuda:0'))
# (-1045, 6, tensor([[6]], device='cuda:0'))
# (-1046, 6, tensor([[6]], device='cuda:0'))
# (-1047, 6, tensor([[6]], device='cuda:0'))
# (-1048, 6, tensor([[6]], device='cuda:0'))
# (-1049, 6, tensor([[6]], device='cuda:0'))
# (-1050, 6, tensor([[6]], device='cuda:0'))
# (-1051, 6, tensor([[6]], device='cuda:0'))
# (-1052, 6, tensor([[6]], device='cuda:0'))
# (-1053, 6, tensor([[6]], device='cuda:0'))
# (-1054, 6, tensor([[6]], device='cuda:0'))
# (-1055, 6, tensor([[6]], device='cuda:0'))
# (-1056, 6, tensor([[6]], device='cuda:0'))
# (-1057, 6, tensor([[6]], device='cuda:0'))
# (-1058, 6, tensor([[6]], device='cuda:0'))
# (-1059, 6, tensor([[6]], device='cuda:0'))
# (-1060, 6, tensor([[6]], device='cuda:0'))
# (-1061, 6, tensor([[6]], device='cuda:0'))
# (-1062, 6, tensor([[6]], device='cuda:0'))
# (-1063, 6, tensor([[6]], device='cuda:0'))
# (-1064, 6, tensor([[6]], device='cuda:0'))
# (-1065, 6, tensor([[6]], device='cuda:0'))
# (-1066, 6, tensor([[6]], device='cuda:0'))
# (-1067, 6, tensor([[6]], device='cuda:0'))
# (-1068, 6, tensor([[6]], device='cuda:0'))
# (-1069, 6, tensor([[6]], device='cuda:0'))
# (-1070, 6, tensor([[6]], device='cuda:0'))
# (-1071, 6, tensor([[6]], device='cuda:0'))
# (-1072, 6, tensor([[6]], device='cuda:0'))
# (-1073, 6, tensor([[6]], device='cuda:0'))
# (-1074, 6, tensor([[6]], device='cuda:0'))
# (-1075, 6, tensor([[6]], device='cuda:0'))
# (-1076, 6, tensor([[6]], device='cuda:0'))
# (-1077, 6, tensor([[6]], device='cuda:0'))
# (-1078, 6, tensor([[6]], device='cuda:0'))
# (-1079, 6, tensor([[6]], device='cuda:0'))
# (-1080, 6, tensor([[6]], device='cuda:0'))
# (-1081, 6, tensor([[6]], device='cuda:0'))
# (-1082, 6, tensor([[6]], device='cuda:0'))
# (-1083, 6, tensor([[6]], device='cuda:0'))
# (-1084, 6, tensor([[6]], device='cuda:0'))
# (-1085, 6, tensor([[6]], device='cuda:0'))
# (-1086, 6, tensor([[6]], device='cuda:0'))
# (-1087, 6, tensor([[6]], device='cuda:0'))
# (-1088, 6, tensor([[6]], device='cuda:0'))
# (-1089, 6, tensor([[6]], device='cuda:0'))
# (-1090, 6, tensor([[6]], device='cuda:0'))
# (-1091, 6, tensor([[6]], device='cuda:0'))
# (-1092, 6, tensor([[6]], device='cuda:0'))
# (-1093, 6, tensor([[6]], device='cuda:0'))
# (-1094, 6, tensor([[6]], device='cuda:0'))
# (-1095, 6, tensor([[6]], device='cuda:0'))
# (-1096, 6, tensor([[6]], device='cuda:0'))
# (-1097, 6, tensor([[6]], device='cuda:0'))
# (-1098, 6, tensor([[6]], device='cuda:0'))
# (-1099, 6, tensor([[6]], device='cuda:0'))
# (-1100, 6, tensor([[6]], device='cuda:0'))
# (-1101, 6, tensor([[6]], device='cuda:0'))
# (-1102, 6, tensor([[6]], device='cuda:0'))
# (-1103, 6, tensor([[6]], device='cuda:0'))
# (-1104, 6, tensor([[6]], device='cuda:0'))
# (-1105, 6, tensor([[6]], device='cuda:0'))
# (-1106, 6, tensor([[6]], device='cuda:0'))
# (-1107, 6, tensor([[6]], device='cuda:0'))
# (-1108, 6, tensor([[6]], device='cuda:0'))
# (-1109, 6, tensor([[6]], device='cuda:0'))
# (-1110, 6, tensor([[6]], device='cuda:0'))
# (-1111, 6, tensor([[6]], device='cuda:0'))
# (-1112, 6, tensor([[6]], device='cuda:0'))
# (-1113, 6, tensor([[6]], device='cuda:0'))
# (-1114, 6, tensor([[6]], device='cuda:0'))
# (-1115, 6, tensor([[6]], device='cuda:0'))
# (-1116, 6, tensor([[6]], device='cuda:0'))
# (-1117, 6, tensor([[6]], device='cuda:0'))
# (-1118, 6, tensor([[6]], device='cuda:0'))
# (-1119, 6, tensor([[6]], device='cuda:0'))
# (-1120, 6, tensor([[6]], device='cuda:0'))
# (-1121, 6, tensor([[6]], device='cuda:0'))
# (-1122, 6, tensor([[6]], device='cuda:0'))
# (-1123, 6, tensor([[6]], device='cuda:0'))
# (-1124, 6, tensor([[6]], device='cuda:0'))
# (-1125, 6, tensor([[6]], device='cuda:0'))
# (-1126, 6, tensor([[6]], device='cuda:0'))
# (-1127, 6, tensor([[6]], device='cuda:0'))
# (-1128, 6, tensor([[6]], device='cuda:0'))
# (-1129, 6, tensor([[6]], device='cuda:0'))
# (-1130, 6, tensor([[6]], device='cuda:0'))
# (-1131, 6, tensor([[6]], device='cuda:0'))
# (-1132, 6, tensor([[6]], device='cuda:0'))
# (-1133, 6, tensor([[6]], device='cuda:0'))
# (-1134, 6, tensor([[6]], device='cuda:0'))
# (-1135, 6, tensor([[6]], device='cuda:0'))
# (-1136, 6, tensor([[6]], device='cuda:0'))
# (-1137, 6, tensor([[6]], device='cuda:0'))
# (-1138, 6, tensor([[6]], device='cuda:0'))
# (-1139, 6, tensor([[6]], device='cuda:0'))
# (-1140, 6, tensor([[6]], device='cuda:0'))
# (-1141, 6, tensor([[6]], device='cuda:0'))
# (-1142, 6, tensor([[6]], device='cuda:0'))
# (-1143, 6, tensor([[6]], device='cuda:0'))
# (-1144, 6, tensor([[6]], device='cuda:0'))
# (-1145, 6, tensor([[6]], device='cuda:0'))
# (-1146, 6, tensor([[6]], device='cuda:0'))
# (-1147, 6, tensor([[6]], device='cuda:0'))
# (-1148, 6, tensor([[6]], device='cuda:0'))
# (-1149, 6, tensor([[6]], device='cuda:0'))
# (-1150, 6, tensor([[6]], device='cuda:0'))
# (-1151, 6, tensor([[6]], device='cuda:0'))
# (-1152, 6, tensor([[6]], device='cuda:0'))
# (-1153, 6, tensor([[6]], device='cuda:0'))
# (-1154, 6, tensor([[6]], device='cuda:0'))
# (-1155, 6, tensor([[6]], device='cuda:0'))
# (-1156, 6, tensor([[6]], device='cuda:0'))
# (-1157, 6, tensor([[6]], device='cuda:0'))
# (-1158, 6, tensor([[6]], device='cuda:0'))
# (-1159, 6, tensor([[6]], device='cuda:0'))
# (-1160, 6, tensor([[6]], device='cuda:0'))
# (-1161, 6, tensor([[6]], device='cuda:0'))
# (-1162, 6, tensor([[6]], device='cuda:0'))
# (-1163, 6, tensor([[6]], device='cuda:0'))
# (-1164, 6, tensor([[6]], device='cuda:0'))
# (-1165, 6, tensor([[6]], device='cuda:0'))
# (-1166, 6, tensor([[6]], device='cuda:0'))
# (-1167, 6, tensor([[6]], device='cuda:0'))
# (-1168, 6, tensor([[6]], device='cuda:0'))
# (-1169, 6, tensor([[6]], device='cuda:0'))
# (-1170, 6, tensor([[6]], device='cuda:0'))
# (-1171, 6, tensor([[6]], device='cuda:0'))
# (-1172, 6, tensor([[6]], device='cuda:0'))
# (-1173, 6, tensor([[6]], device='cuda:0'))
# (-1174, 6, tensor([[6]], device='cuda:0'))
# (-1175, 6, tensor([[6]], device='cuda:0'))
# (-1176, 6, tensor([[6]], device='cuda:0'))
# (-1177, 6, tensor([[6]], device='cuda:0'))
# (-1178, 6, tensor([[6]], device='cuda:0'))
# (-1179, 6, tensor([[6]], device='cuda:0'))
# (-1180, 6, tensor([[6]], device='cuda:0'))
# (-1181, 6, tensor([[6]], device='cuda:0'))
# (-1182, 6, tensor([[6]], device='cuda:0'))
# (-1183, 6, tensor([[6]], device='cuda:0'))
# (-1184, 6, tensor([[6]], device='cuda:0'))
# (-1185, 6, tensor([[6]], device='cuda:0'))
# (-1186, 6, tensor([[6]], device='cuda:0'))
# (-1187, 6, tensor([[6]], device='cuda:0'))
# (-1188, 6, tensor([[6]], device='cuda:0'))
# (-1189, 6, tensor([[6]], device='cuda:0'))
# (-1190, 6, tensor([[6]], device='cuda:0'))
# (-1191, 6, tensor([[6]], device='cuda:0'))
# (-1192, 6, tensor([[6]], device='cuda:0'))
# (-1193, 6, tensor([[6]], device='cuda:0'))
# (-1194, 6, tensor([[6]], device='cuda:0'))
# (-1195, 6, tensor([[6]], device='cuda:0'))
# (-1196, 6, tensor([[6]], device='cuda:0'))
# (-1197, 6, tensor([[6]], device='cuda:0'))
# (-1198, 6, tensor([[6]], device='cuda:0'))
# (-1199, 6, tensor([[6]], device='cuda:0'))
# (-1200, 6, tensor([[6]], device='cuda:0'))
# (-1201, 6, tensor([[6]], device='cuda:0'))
# (-1202, 6, tensor([[6]], device='cuda:0'))
# (-1203, 6, tensor([[6]], device='cuda:0'))
# (-1204, 6, tensor([[6]], device='cuda:0'))
# (-1205, 6, tensor([[6]], device='cuda:0'))
# (-1206, 6, tensor([[6]], device='cuda:0'))
# (-1207, 6, tensor([[6]], device='cuda:0'))
# (-1208, 6, tensor([[6]], device='cuda:0'))
# (-1209, 6, tensor([[6]], device='cuda:0'))
# (-1210, 6, tensor([[6]], device='cuda:0'))
# (-1211, 6, tensor([[6]], device='cuda:0'))
# (-1212, 6, tensor([[6]], device='cuda:0'))
# (-1213, 6, tensor([[6]], device='cuda:0'))
# (-1214, 6, tensor([[6]], device='cuda:0'))
# (-1215, 6, tensor([[6]], device='cuda:0'))
# (-1216, 6, tensor([[6]], device='cuda:0'))
# (-1217, 6, tensor([[6]], device='cuda:0'))
# (-1218, 6, tensor([[6]], device='cuda:0'))
# (-1219, 6, tensor([[6]], device='cuda:0'))
# (-1220, 6, tensor([[6]], device='cuda:0'))
# (-1221, 6, tensor([[6]], device='cuda:0'))
# (-1222, 6, tensor([[6]], device='cuda:0'))
# (-1223, 6, tensor([[6]], device='cuda:0'))
# (-1224, 6, tensor([[6]], device='cuda:0'))
# (-1225, 6, tensor([[6]], device='cuda:0'))
# (-1226, 6, tensor([[6]], device='cuda:0'))
# (-1227, 6, tensor([[6]], device='cuda:0'))
# (-1228, 6, tensor([[6]], device='cuda:0'))
# (-1229, 6, tensor([[6]], device='cuda:0'))
# (-1230, 6, tensor([[6]], device='cuda:0'))
# (-1231, 6, tensor([[6]], device='cuda:0'))
# (-1232, 6, tensor([[6]], device='cuda:0'))
# (-1233, 6, tensor([[6]], device='cuda:0'))
# (-1234, 6, tensor([[6]], device='cuda:0'))
# (-1235, 6, tensor([[6]], device='cuda:0'))
# (-1236, 6, tensor([[6]], device='cuda:0'))
# (-1237, 6, tensor([[6]], device='cuda:0'))
# (-1238, 6, tensor([[6]], device='cuda:0'))
# (-1239, 6, tensor([[6]], device='cuda:0'))
# (-1240, 6, tensor([[6]], device='cuda:0'))
# (-1241, 6, tensor([[6]], device='cuda:0'))
# (-1242, 6, tensor([[6]], device='cuda:0'))
# (-1243, 6, tensor([[6]], device='cuda:0'))
# (-1244, 6, tensor([[6]], device='cuda:0'))
# (-1245, 6, tensor([[6]], device='cuda:0'))
# (-1246, 6, tensor([[6]], device='cuda:0'))
# (-1247, 6, tensor([[6]], device='cuda:0'))
# (-1248, 6, tensor([[6]], device='cuda:0'))
# (-1249, 6, tensor([[6]], device='cuda:0'))
# (-1250, 6, tensor([[6]], device='cuda:0'))
# (-1251, 6, tensor([[6]], device='cuda:0'))
# (-1252, 6, tensor([[6]], device='cuda:0'))
# (-1253, 6, tensor([[6]], device='cuda:0'))
# (-1254, 6, tensor([[6]], device='cuda:0'))
# (-1255, 6, tensor([[6]], device='cuda:0'))
# (-1256, 6, tensor([[6]], device='cuda:0'))
# (-1257, 6, tensor([[6]], device='cuda:0'))
# (-1258, 6, tensor([[6]], device='cuda:0'))
# (-1259, 6, tensor([[6]], device='cuda:0'))
# (-1260, 6, tensor([[6]], device='cuda:0'))
# (-1261, 6, tensor([[6]], device='cuda:0'))
# (-1262, 6, tensor([[6]], device='cuda:0'))
# (-1263, 6, tensor([[6]], device='cuda:0'))
# (-1264, 6, tensor([[6]], device='cuda:0'))
# (-1265, 6, tensor([[6]], device='cuda:0'))
# (-1266, 6, tensor([[6]], device='cuda:0'))
# (-1267, 6, tensor([[6]], device='cuda:0'))
# (-1268, 6, tensor([[6]], device='cuda:0'))
# (-1269, 6, tensor([[6]], device='cuda:0'))
# (-1270, 6, tensor([[6]], device='cuda:0'))
# (-1271, 6, tensor([[6]], device='cuda:0'))
# (-1272, 6, tensor([[6]], device='cuda:0'))
# (-1273, 6, tensor([[6]], device='cuda:0'))
# (-1274, 6, tensor([[6]], device='cuda:0'))
# (-1275, 6, tensor([[6]], device='cuda:0'))
# (-1276, 6, tensor([[6]], device='cuda:0'))
# (-1277, 6, tensor([[6]], device='cuda:0'))
# (-1278, 6, tensor([[6]], device='cuda:0'))
# (-1279, 6, tensor([[6]], device='cuda:0'))
# (-1280, 6, tensor([[6]], device='cuda:0'))
# (-1281, 6, tensor([[6]], device='cuda:0'))
# (-1282, 6, tensor([[6]], device='cuda:0'))
# (-1283, 6, tensor([[6]], device='cuda:0'))
# (-1284, 6, tensor([[6]], device='cuda:0'))
# (-1285, 6, tensor([[6]], device='cuda:0'))
# (-1286, 6, tensor([[6]], device='cuda:0'))
# (-1287, 6, tensor([[6]], device='cuda:0'))
# (-1288, 6, tensor([[6]], device='cuda:0'))
# (-1289, 6, tensor([[6]], device='cuda:0'))
# (-1290, 6, tensor([[6]], device='cuda:0'))
# (-1291, 6, tensor([[6]], device='cuda:0'))
# (-1292, 6, tensor([[6]], device='cuda:0'))
# (-1293, 6, tensor([[6]], device='cuda:0'))
# (-1294, 6, tensor([[6]], device='cuda:0'))
# (-1295, 6, tensor([[6]], device='cuda:0'))
# (-1296, 6, tensor([[6]], device='cuda:0'))
# (-1297, 6, tensor([[6]], device='cuda:0'))
# (-1298, 6, tensor([[6]], device='cuda:0'))
# (-1299, 6, tensor([[6]], device='cuda:0'))
# (-1300, 6, tensor([[6]], device='cuda:0'))
# (-1301, 6, tensor([[6]], device='cuda:0'))
# (-1302, 6, tensor([[6]], device='cuda:0'))
# (-1303, 6, tensor([[6]], device='cuda:0'))
# (-1304, 6, tensor([[6]], device='cuda:0'))
# (-1305, 6, tensor([[6]], device='cuda:0'))
# (-1306, 6, tensor([[6]], device='cuda:0'))
# (-1307, 6, tensor([[6]], device='cuda:0'))
# (-1308, 6, tensor([[6]], device='cuda:0'))
# (-1309, 6, tensor([[6]], device='cuda:0'))
# (-1310, 6, tensor([[6]], device='cuda:0'))
# (-1311, 6, tensor([[6]], device='cuda:0'))
# (-1312, 6, tensor([[6]], device='cuda:0'))
# (-1313, 6, tensor([[6]], device='cuda:0'))
# (-1314, 6, tensor([[6]], device='cuda:0'))
# (-1315, 6, tensor([[6]], device='cuda:0'))
# (-1316, 6, tensor([[6]], device='cuda:0'))
# (-1317, 6, tensor([[6]], device='cuda:0'))
# (-1318, 6, tensor([[6]], device='cuda:0'))
# (-1319, 6, tensor([[6]], device='cuda:0'))
# (-1320, 6, tensor([[6]], device='cuda:0'))
# (-1321, 6, tensor([[6]], device='cuda:0'))
# (-1322, 6, tensor([[6]], device='cuda:0'))
# (-1323, 6, tensor([[6]], device='cuda:0'))
# (-1324, 6, tensor([[6]], device='cuda:0'))
# (-1325, 6, tensor([[6]], device='cuda:0'))
# (-1326, 6, tensor([[6]], device='cuda:0'))
# (-1327, 6, tensor([[6]], device='cuda:0'))
# (-1328, 6, tensor([[6]], device='cuda:0'))
# (-1329, 6, tensor([[6]], device='cuda:0'))
# (-1330, 6, tensor([[6]], device='cuda:0'))
# (-1331, 6, tensor([[6]], device='cuda:0'))
# (-1332, 6, tensor([[6]], device='cuda:0'))
# (-1333, 6, tensor([[6]], device='cuda:0'))
# (-1334, 6, tensor([[6]], device='cuda:0'))
# (-1335, 6, tensor([[6]], device='cuda:0'))
# (-1336, 6, tensor([[6]], device='cuda:0'))
# (-1337, 6, tensor([[6]], device='cuda:0'))
# (-1338, 6, tensor([[6]], device='cuda:0'))
# (-1339, 6, tensor([[6]], device='cuda:0'))
# (-1340, 6, tensor([[6]], device='cuda:0'))
# (-1341, 6, tensor([[6]], device='cuda:0'))
# (-1342, 6, tensor([[6]], device='cuda:0'))
# (-1343, 6, tensor([[6]], device='cuda:0'))
# (-1344, 6, tensor([[6]], device='cuda:0'))
# (-1345, 6, tensor([[6]], device='cuda:0'))
# (-1346, 6, tensor([[6]], device='cuda:0'))
# (-1347, 6, tensor([[6]], device='cuda:0'))
# (-1348, 6, tensor([[6]], device='cuda:0'))
# (-1349, 6, tensor([[6]], device='cuda:0'))
# (-1350, 6, tensor([[6]], device='cuda:0'))
# (-1351, 6, tensor([[6]], device='cuda:0'))
# (-1352, 6, tensor([[6]], device='cuda:0'))
# (-1353, 6, tensor([[6]], device='cuda:0'))
# (-1354, 6, tensor([[6]], device='cuda:0'))
# (-1355, 6, tensor([[6]], device='cuda:0'))
# (-1356, 6, tensor([[6]], device='cuda:0'))
# (-1357, 6, tensor([[6]], device='cuda:0'))
# (-1358, 6, tensor([[6]], device='cuda:0'))
# (-1359, 6, tensor([[6]], device='cuda:0'))
# (-1360, 6, tensor([[6]], device='cuda:0'))
# (-1361, 6, tensor([[6]], device='cuda:0'))
# (-1362, 6, tensor([[6]], device='cuda:0'))
# (-1363, 6, tensor([[6]], device='cuda:0'))
# (-1364, 6, tensor([[6]], device='cuda:0'))
# (-1365, 6, tensor([[6]], device='cuda:0'))
# (-1366, 6, tensor([[6]], device='cuda:0'))
# (-1367, 6, tensor([[6]], device='cuda:0'))
# (-1368, 6, tensor([[6]], device='cuda:0'))
# (-1369, 6, tensor([[6]], device='cuda:0'))
# (-1370, 6, tensor([[6]], device='cuda:0'))
# (-1371, 6, tensor([[6]], device='cuda:0'))
# (-1372, 6, tensor([[6]], device='cuda:0'))
# (-1373, 6, tensor([[6]], device='cuda:0'))
# (-1374, 6, tensor([[6]], device='cuda:0'))
# (-1375, 6, tensor([[6]], device='cuda:0'))
# (-1376, 6, tensor([[6]], device='cuda:0'))
# (-1377, 6, tensor([[6]], device='cuda:0'))
# (-1378, 6, tensor([[6]], device='cuda:0'))
# (-1379, 6, tensor([[6]], device='cuda:0'))
# (-1380, 6, tensor([[6]], device='cuda:0'))
# (-1381, 6, tensor([[6]], device='cuda:0'))
# (-1382, 6, tensor([[6]], device='cuda:0'))
# (-1383, 6, tensor([[6]], device='cuda:0'))
# (-1384, 6, tensor([[6]], device='cuda:0'))
# (-1385, 6, tensor([[6]], device='cuda:0'))
# (-1386, 6, tensor([[6]], device='cuda:0'))
# (-1387, 6, tensor([[6]], device='cuda:0'))
# (-1388, 6, tensor([[6]], device='cuda:0'))
# (-1389, 6, tensor([[6]], device='cuda:0'))
# (-1390, 6, tensor([[6]], device='cuda:0'))
# (-1391, 6, tensor([[6]], device='cuda:0'))
# (-1392, 6, tensor([[6]], device='cuda:0'))
# (-1393, 6, tensor([[6]], device='cuda:0'))
# (-1394, 6, tensor([[6]], device='cuda:0'))
# (-1395, 6, tensor([[6]], device='cuda:0'))
# (-1396, 6, tensor([[6]], device='cuda:0'))
# (-1397, 6, tensor([[6]], device='cuda:0'))
# (-1398, 6, tensor([[6]], device='cuda:0'))
# (-1399, 6, tensor([[6]], device='cuda:0'))
# (-1400, 6, tensor([[6]], device='cuda:0'))
# (-1401, 6, tensor([[6]], device='cuda:0'))
# (-1402, 6, tensor([[6]], device='cuda:0'))
# (-1403, 6, tensor([[6]], device='cuda:0'))
# (-1404, 6, tensor([[6]], device='cuda:0'))
# (-1405, 6, tensor([[6]], device='cuda:0'))
# (-1406, 6, tensor([[6]], device='cuda:0'))
# (-1407, 6, tensor([[6]], device='cuda:0'))
# (-1408, 6, tensor([[6]], device='cuda:0'))
# (-1409, 6, tensor([[6]], device='cuda:0'))
# (-1410, 6, tensor([[6]], device='cuda:0'))
# (-1411, 6, tensor([[6]], device='cuda:0'))
# (-1412, 6, tensor([[6]], device='cuda:0'))
# (-1413, 6, tensor([[6]], device='cuda:0'))
# (-1414, 6, tensor([[6]], device='cuda:0'))
# (-1415, 6, tensor([[6]], device='cuda:0'))
# (-1416, 6, tensor([[6]], device='cuda:0'))
# (-1417, 6, tensor([[6]], device='cuda:0'))
# (-1418, 6, tensor([[6]], device='cuda:0'))
# (-1419, 6, tensor([[6]], device='cuda:0'))
# (-1420, 6, tensor([[6]], device='cuda:0'))
# (-1421, 6, tensor([[6]], device='cuda:0'))
# (-1422, 6, tensor([[6]], device='cuda:0'))
# (-1423, 6, tensor([[6]], device='cuda:0'))
# (-1424, 6, tensor([[6]], device='cuda:0'))
# (-1425, 6, tensor([[6]], device='cuda:0'))
# (-1426, 6, tensor([[6]], device='cuda:0'))
# (-1427, 6, tensor([[6]], device='cuda:0'))
# (-1428, 6, tensor([[6]], device='cuda:0'))
# (-1429, 6, tensor([[6]], device='cuda:0'))
# (-1430, 6, tensor([[6]], device='cuda:0'))
# (-1431, 6, tensor([[6]], device='cuda:0'))
# (-1432, 6, tensor([[6]], device='cuda:0'))
# (-1433, 6, tensor([[6]], device='cuda:0'))
# (-1434, 6, tensor([[6]], device='cuda:0'))
# (-1435, 6, tensor([[6]], device='cuda:0'))
# (-1436, 6, tensor([[6]], device='cuda:0'))
# (-1437, 6, tensor([[6]], device='cuda:0'))
# (-1438, 6, tensor([[6]], device='cuda:0'))
# (-1439, 6, tensor([[6]], device='cuda:0'))
# (-1440, 6, tensor([[6]], device='cuda:0'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 40
#      35             print((rtgs[-1], action, state))
#      36             # print((rtgs[-1], action, state))
#      37             # all_states has all previous states and rtgs has all revious rtgs (will be cut to block_size in trainer.generate)
#      38             # timestep is just the current timestep
#      39             sampled_action = model.generate(all_states.unsqueeze(0), 1, temperature=1.0, do_sample=True,
# ---> 40                             actions=torch.tensor(actions, dtype=torch.long).to(trainer.device).unsqueeze(-1).unsqueeze(0),
#      41                             rtgs=torch.tensor(rtgs, dtype=torch.long).to(trainer.device).unsqueeze(0).unsqueeze(-1),
#      42                             timesteps=(min(j, model.config.max_timestep) * torch.ones((1, 1, 1), dtype=torch.int64).to(trainer.device)))
#      43 print((rtgs[-1], action, state))
#
# KeyboardInterrupt:

# %%
state = torch.tensor(env.reset())
state = state.type(torch.float32).to(trainer.device).unsqueeze(0).unsqueeze(0)
# print(state)
rtgs = torch.tensor(-2, dtype=torch.long).to(trainer.device).unsqueeze(0).unsqueeze(-1)
model.generate(state, 1, temperature=0.1, do_sample=True, rtgs=rtgs, timesteps=torch.zeros((1, 1, 1), dtype=torch.int64).to(trainer.device))
# Out:
# tensor([[5]], device='cuda:0')
